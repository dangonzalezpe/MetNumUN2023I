# %% [markdown]
# **Data Analysis with Python**

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/223f19cbe4574f02bf59d3ac6b48b1d7

# %% [markdown]
# ![Curso2.jpg](data:image/jpeg;base64,...)
