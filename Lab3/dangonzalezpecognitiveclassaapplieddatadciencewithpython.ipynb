# %% [markdown]
# **Perfil de LinkedIn**

# %% [markdown]
# https://www.linkedin.com/in/daniel-sebasti%C3%A1n-gonz%C3%A1lez-pedraza-b76a50268/

# %% [markdown]
# **Captura de LinkedIn**

# %% [markdown]
# ![Captura de pantalla 2023-03-04 210056.jpg](data:image/jpeg;base64,...)
