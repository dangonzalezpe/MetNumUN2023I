# %% [markdown]
# **Data Visualization with Python**

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/56cef77953664004818de275aa40a9f9

# %% [markdown]
# ![Curso3.jpg](data:image/jpeg;base64,...)
